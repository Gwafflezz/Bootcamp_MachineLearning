# %%
import pandas as pd

# %%
# carregando os arquivos
r_cols = ['user_id', 'movie_id','rating'] # nomes das colunas de avaliações
ratings = pd.read_csv('u.data', sep= '\t',names = r_cols, usecols=range(3), encoding="ISO-8859-1")

m_cols = ['movie_id', 'title']
movies = pd.read_csv('u.item', sep = '|', names = m_cols, usecols = range(2), encoding= "ISO-8859-1")
ratings = pd.merge(movies, ratings) # unificando os dois dataframes

# %%
userRatings = ratings.pivot_table(index=['user_id'], columns = ['title'], values = 'rating')
userRatings.head()
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 0                        NaN         NaN                          NaN
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# ...

# %%
corrMatrix =  userRatings.corr()
corrMatrix.head()
# Out:
# title                      'Til There Was You (1997)  1-900 (1994)  \
# title
# 'Til There Was You (1997)                        1.0           NaN
# 1-900 (1994)                                     NaN           1.0
# 101 Dalmatians (1996)                           -1.0           NaN
# 12 Angry Men (1957)                             -0.5           NaN
# 187 (1997)                                      -0.5           NaN
#
# title                      101 Dalmatians (1996)  12 Angry Men (1957)  \
# title
# 'Til There Was You (1997)              -1.000000            -0.500000
# 1-900 (1994)                                 NaN                  NaN
# 101 Dalmatians (1996)                   1.000000            -0.049890
# 12 Angry Men (1957)                    -0.049890             1.000000
# 187 (1997)                              0.269191             0.666667
#
# title                      187 (1997)  2 Days in the Valley (1996)  \
# title
# ...

# %%
corrMatrix = userRatings.corr(method = 'pearson',min_periods = 100)#descartando entradas om menos de 100 valiações
corrMatrix.head()
# Out:
# title                      'Til There Was You (1997)  1-900 (1994)  \
# title
# 'Til There Was You (1997)                        NaN           NaN
# 1-900 (1994)                                     NaN           NaN
# 101 Dalmatians (1996)                            NaN           NaN
# 12 Angry Men (1957)                              NaN           NaN
# 187 (1997)                                       NaN           NaN
#
# title                      101 Dalmatians (1996)  12 Angry Men (1957)  \
# title
# 'Til There Was You (1997)                    NaN                  NaN
# 1-900 (1994)                                 NaN                  NaN
# 101 Dalmatians (1996)                        1.0                  NaN
# 12 Angry Men (1957)                          NaN                  1.0
# 187 (1997)                                   NaN                  NaN
#
# title                      187 (1997)  2 Days in the Valley (1996)  \
# title
# ...

# %%
myRatings = userRatings.loc[0].dropna()
myRatings
# Out:
# title
# Empire Strikes Back, The (1980)    5.0
# Gone with the Wind (1939)          1.0
# Star Wars (1977)                   5.0
# Name: 0, dtype: float64

# %%
simCandidates = pd.Series() 

# somar filmes similares aos classificados 
for i in range(0, len(myRatings.index)):
    print('Adding sims for ' + str(myRatings.index[i]) + '...')
    sims = corrMatrix[myRatings.index[i]].dropna()
    sims = sims.map(lambda x: x * myRatings[1])
    simCandidates = simCandidates._append(sims)

print('Sorting...')
# ordenando 
simCandidates.sort_values(inplace=True, ascending=False)
print(simCandidates.head(10))
# Out:
# Adding sims for Empire Strikes Back, The (1980)...
# Adding sims for Gone with the Wind (1939)...
# Adding sims for Star Wars (1977)...
# Sorting...
# Empire Strikes Back, The (1980)    1.000000
# Star Wars (1977)                   1.000000
# Gone with the Wind (1939)          1.000000
# Star Wars (1977)                   0.748353
# Empire Strikes Back, The (1980)    0.748353
# Return of the Jedi (1983)          0.721229
# Return of the Jedi (1983)          0.672556
# Raiders of the Lost Ark (1981)     0.538659
# Raiders of the Lost Ark (1981)     0.536117
# Wizard of Oz, The (1939)           0.430219
# dtype: float64
# /tmp/ipykernel_6931/3905288874.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sims = sims.map(lambda x: x * myRatings[1])
# ...

# %%
simCandidates = simCandidates.groupby(simCandidates.index).sum()

# %%
simCandidates.sort_values(inplace = True, ascending = False)
simCandidates.head(15)
# Out:
# Empire Strikes Back, The (1980)              1.884040
# Star Wars (1977)                             1.877560
# Return of the Jedi (1983)                    1.603032
# Gone with the Wind (1939)                    1.264895
# Raiders of the Lost Ark (1981)               1.220594
# Wizard of Oz, The (1939)                     0.984229
# E.T. the Extra-Terrestrial (1982)            0.883620
# Back to the Future (1985)                    0.877443
# Indiana Jones and the Last Crusade (1989)    0.834655
# Casablanca (1942)                            0.809604
# Field of Dreams (1989)                       0.767504
# Sting, The (1973)                            0.762141
# It's a Wonderful Life (1946)                 0.751772
# Lion King, The (1994)                        0.711759
# Jaws (1975)                                  0.694473
# dtype: float64

# %%
simCandidates.head(25)
# Out:
# Empire Strikes Back, The (1980)              1.884040
# Star Wars (1977)                             1.877560
# Return of the Jedi (1983)                    1.603032
# Gone with the Wind (1939)                    1.264895
# Raiders of the Lost Ark (1981)               1.220594
# Wizard of Oz, The (1939)                     0.984229
# E.T. the Extra-Terrestrial (1982)            0.883620
# Back to the Future (1985)                    0.877443
# Indiana Jones and the Last Crusade (1989)    0.834655
# Casablanca (1942)                            0.809604
# Field of Dreams (1989)                       0.767504
# Sting, The (1973)                            0.762141
# It's a Wonderful Life (1946)                 0.751772
# Lion King, The (1994)                        0.711759
# Jaws (1975)                                  0.694473
# Terminator 2: Judgment Day (1991)            0.674346
# Bridge on the River Kwai, The (1957)         0.673323
# ...
