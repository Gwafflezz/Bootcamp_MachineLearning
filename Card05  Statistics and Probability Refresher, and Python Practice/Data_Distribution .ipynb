# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
values = np.random.uniform(-10.0,10.0,10000)
plt.hist(values,50)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
#  Distribuição uniforme apresenta igual probabilidade para todos os valores

# %% [markdown]
# # Normal / Gaussiana

# %%
from scipy.stats import norm
import matplotlib.pyplot as plt
x = np.arange(-3,3,0.001)
plt.plot(x,norm.pdf(x))

# %%
mu = 5.0
sigma = 2.0
values = np.random.normal(mu, sigma, 10000)
plt.hist(values,50)
plt.show()

# %% [markdown]
# # Função de distribuiçao exponencial

# %%
from scipy.stats import expon
x = np.arange(0,10,0.001)
plt.plot(x, expon.pdf(x))

# %% [markdown]
# # Função de Distribuiçao Binomial

# %%
from scipy.stats import binom

n,p = 10, 0.5
x = np.arange(0, 10, 0.001)
plt.plot(x,binom.pmf(x,n,p))

# %%
# apresenda dados discretos
