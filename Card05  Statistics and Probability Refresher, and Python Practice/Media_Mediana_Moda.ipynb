# %%
import numpy as np

# %%
incomes = np.random.normal(27000,15000,10000)
np.mean(incomes)
# Out:
# 27155.055181933694

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.hist(incomes,50)
plt.show()

# %%
np.median(incomes)
# Out:
# 27202.79781501788

# %%
incomes = np.append(incomes,[1000000000])

# %%
np.median(incomes)
# Out:
# 27203.796247255228

# %%
np.mean(incomes)
# Out:
# 127142.34094783891

# %% [markdown]
# # Moda

# %%
ages = np.random.randint(18,high=90,size=500)
ages
# Out:
# array([76, 28, 75, 35, 33, 61, 19, 49, 26, 73, 50, 83, 76, 69, 46, 50, 80,
#        61, 54, 66, 28, 36, 60, 35, 68, 83, 62, 56, 49, 75, 59, 80, 69, 63,
#        43, 32, 65, 28, 52, 66, 39, 33, 27, 81, 41, 83, 51, 18, 35, 57, 43,
#        33, 44, 30, 75, 18, 80, 68, 69, 26, 57, 85, 59, 22, 25, 85, 38, 18,
#        21, 88, 77, 18, 44, 60, 60, 82, 61, 35, 73, 23, 36, 51, 44, 57, 49,
#        32, 36, 45, 84, 65, 42, 75, 48, 32, 72, 48, 84, 82, 88, 58, 66, 82,
#        49, 57, 73, 19, 35, 88, 48, 70, 83, 57, 88, 43, 50, 35, 84, 62, 47,
#        39, 76, 89, 60, 63, 29, 31, 76, 76, 38, 75, 83, 42, 39, 63, 23, 31,
#        49, 43, 62, 26, 75, 54, 41, 25, 67, 73, 78, 34, 59, 62, 23, 65, 20,
#        57, 70, 22, 66, 73, 42, 53, 87, 37, 45, 82, 55, 38, 52, 51, 74, 36,
#        35, 74, 54, 27, 34, 33, 21, 65, 67, 43, 86, 72, 53, 35, 27, 62, 84,
#        82, 85, 70, 75, 68, 88, 22, 42, 86, 77, 53, 56, 19, 73, 37, 78, 70,
#        53, 80, 37, 40, 68, 85, 77, 55, 85, 49, 36, 52, 41, 25, 40, 87, 41,
#        56, 19, 59, 84, 63, 20, 74, 45, 55, 29, 43, 67, 25, 25, 27, 51, 55,
#        81, 28, 61, 26, 45, 51, 18, 75, 31, 83, 51, 79, 44, 36, 49, 20, 49,
#        33, 71, 62, 69, 80, 21, 64, 43, 85, 34, 50, 22, 80, 47, 86, 50, 28,
#        79, 24, 48, 39, 28, 89, 21, 87, 67, 89, 69, 85, 34, 32, 18, 61, 27,
#        23, 19, 23, 30, 43, 54, 80, 71, 73, 88, 36, 79, 61, 88, 42, 49, 20,
#        82, 51, 31, 66, 43, 89, 43, 76, 19, 59, 42, 63, 67, 54, 46, 47, 68,
#        71, 88, 43, 62, 31, 63, 19, 42, 26, 38, 19, 44, 31, 83, 22, 44, 83,
#        71, 75, 34, 63, 62, 70, 62, 70, 64, 51, 80, 81, 26, 46, 53, 65, 78,
#        84, 71, 68, 32, 65, 85, 51, 33, 61, 47, 40, 84, 52, 38, 59, 72, 55,
#        59, 19, 59, 31, 30, 41, 61, 31, 23, 44, 19, 44, 76, 46, 76, 34, 79,
#        59, 35, 24, 88, 65, 24, 19, 56, 31, 30, 46, 33, 63, 45, 36, 58, 73,
#        56, 23, 35, 51, 49, 54, 33, 33, 83, 87, 33, 43, 35, 36, 62, 55, 20,
#        46, 22, 39, 39, 41, 82, 29, 73, 45, 61, 47, 58, 21, 59, 59, 89, 65,
#        36, 47, 28, 39, 74, 53, 23, 82, 50, 24, 63, 69, 29, 66, 70, 50, 36,
#        75, 40, 24, 71, 73, 59, 47, 40, 63, 80, 51, 68, 60, 81, 24, 64, 74,
#        79, 52, 35, 28, 76, 18, 69, 47, 64, 76, 55, 60, 64, 81, 59, 32, 79,
#        20, 57, 86, 71, 65, 53, 77])

# %%
from scipy import stats
stats.mode(ages)
# Out:
# ModeResult(mode=59, count=13)

# %% [markdown]
# # Assignment

# %%
incomes = np.random.normal(100.0,20.0,10000)
plt.hist(incomes,50)
plt.show()

# %%
np.median(incomes)
# Out:
# 99.84217311962672

# %%
np.mean(incomes)
# Out:
# 99.86400400917807

# %%
stats.mode(incomes)
# Out:
# ModeResult(mode=30.267284664792527, count=1)
