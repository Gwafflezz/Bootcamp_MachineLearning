# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
incomes = np.random.normal(100.0,20.0,10000)
plt.hist(incomes,50)
plt.show()

# %%
incomes.std()
# Out:
# 20.156144513140116

# %%
incomes.var()
# Out:
# 406.2701616345885
