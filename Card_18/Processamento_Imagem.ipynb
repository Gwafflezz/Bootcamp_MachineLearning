# %% [markdown]
# Imagem: url https://wallpaper.dog/large/5502413.jpg

# %%
# !wget https://wallpaper.dog/large/5502413.jpg
# Out:
# --2024-08-28 16:52:59--  https://wallpaper.dog/large/5502413.jpg
# Resolving wallpaper.dog (wallpaper.dog)... 104.21.62.211, 172.67.139.86, 2606:4700:3030::ac43:8b56, ...
# Connecting to wallpaper.dog (wallpaper.dog)|104.21.62.211|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 470328 (459K) [image/jpeg]
# Saving to: ‘5502413.jpg.1’
#
# 5502413.jpg.1       100%[===================>] 459.30K  --.-KB/s    in 0.05s
#
# 2024-08-28 16:52:59 (9.30 MB/s) - ‘5502413.jpg.1’ saved [470328/470328]

# %%
# !ls
# Out:
# 5502413.jpg  5502413.jpg.1  sample_data

# %% [markdown]
# lendo a imagem com opencv

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
img = cv.imread('5502413.jpg.1')

# %%
plt.imshow(img)

# %%
rgb_image = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(rgb_image)

# %%
gray_image = cv.cvtColor(rgb_image, cv.COLOR_RGB2GRAY)

# %%
plt.imshow(gray_image, cmap='gray')

# %%
rgb_image.shape
# Out:
# (1080, 1920, 3)

# %%
gray_image.shape
# Out:
# (1080, 1920)

# %% [markdown]
# Redimensionamento da imagem

# %%
img_gray_small = cv.resize(gray_image,(100,100))
plt.imshow(img_gray_small, cmap='gray')

# %%
plt.imshow(gray_image[10:400,:], cmap='gray')

# %%
plt.imshow(gray_image[:,:500], cmap='gray')
